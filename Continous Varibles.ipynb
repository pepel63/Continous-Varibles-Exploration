# %%
pip install plotnine
# Out:
# ...
#   Using cached plotnine-0.13.6-py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached mizani-0.11.3-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached plotnine-0.13.6-py3-none-any.whl (1.3 MB)
# Using cached mizani-0.11.3-py3-none-any.whl (127 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the necessary libraries
from plotnine import ggplot, aes, geom_point, theme_minimal
import pandas as pd

# Create a sample DataFrame
df = pd.read_csv("pbc.csv")

# Create a ggplot2-like plot
(ggplot(df, aes(x='age', y='bili'))
 + geom_point()
 + theme_minimal()
)

# %%
from plotnine import ggplot, aes, geom_histogram, theme_minimal

(ggplot(df, aes(x='chol'))
 + geom_histogram(bins=30)  # Adjust the number of bins as needed
 + theme_minimal()
)
# Out:
# C:\Users\singa\anaconda3\Lib\site-packages\plotnine\layer.py:284: PlotnineWarning: stat_bin : Removed 134 rows containing non-finite values.

# %%
from plotnine import ggplot, aes,geom_area
x + geom_area(stat='bin', fill='indianred')
# Out:
# C:\Users\singa\anaconda3\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 42'. Pick better value with 'binwidth'.
# C:\Users\singa\anaconda3\Lib\site-packages\plotnine\layer.py:284: PlotnineWarning: stat_bin : Removed 134 rows containing non-finite values.

# %%
from plotnine import ggplot, aes, geom_histogram

# Assuming df is your DataFrame and 'chol' is the column of interest

# First histogram with specified color and fill
hist1 = x + geom_histogram(color='darkslategrey', fill='lightblue', bins=30)

# Second histogram with fill based on the 'sex' column
hist2 = x + geom_histogram(aes(fill='sex'), bins=30)


# For example, in a Jupyter notebook:
hist1
hist2

# %%
from plotnine import ggplot, aes, geom_bar, theme_minimal, xlim

# Assuming 'df' is your DataFrame and 'edema' is the column of interest
y = ggplot(df, aes(x='edema')) + \
    geom_bar(fill="orange") + \
    xlim(-5, 1.5) + \
    theme_minimal()

# Save the plot
y
